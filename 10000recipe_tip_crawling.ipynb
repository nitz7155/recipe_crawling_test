# %%
import requests
import csv
import time
import random
import os
import glob
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
from tqdm import tqdm

# %%
# ------------------------------------------------------------------------------
# [설정] 헤더 및 URL
# ------------------------------------------------------------------------------
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

# 매거진(알아두면 좋은 꿀팁) 리스트 URL (페이지 번호는 뒤에 붙임)
magazine_list_url = "https://www.10000recipe.com/issue/view.html?cid=10000know&types=magazine&page="
base_domain = "https://www.10000recipe.com"

# 저장할 CSV 헤더 (팁/매거진에 맞는 항목으로 구성)
fieldnames = [
    'Link', 'Title', 'Main_Thumbnail', 'Intro_Summary', 'Content_Steps'
]

def main():
    # ------------------------------------------------------------------------------
    # [1] 파일 생성 및 이어하기(Resume) 설정
    # ------------------------------------------------------------------------------
    print("=" * 60)
    print(" [만개의 레시피 - 매거진/꿀팁 크롤러] 시작")
    print("=" * 60)

    # 기존 파일 확인
    existing_files = sorted(glob.glob("10000recipe_magazine_*.csv"), key=os.path.getmtime, reverse=True)
    filename = ""
    processed_links = set()

    if existing_files:
        latest_file = existing_files[0]
        print(f"\n[알림] 최근 작업 파일을 발견했습니다: '{latest_file}'")
        resume = input("  -> 이 파일에 이어서 작업하시겠습니까? (y/n): ").strip().lower()
        if resume == 'y':
            filename = latest_file
            try:
                with open(filename, 'r', encoding='utf-8-sig') as f:
                    reader = csv.DictReader(f)
                    for row in reader:
                        if 'Link' in row and row['Link']:
                            processed_links.add(row['Link'])
                print(f"  -> ✅ 이미 수집된 {len(processed_links)}개의 글을 건너뜁니다.")
            except:
                filename = ""

    if not filename:
        filename = f"10000recipe_magazine_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
        with open(filename, 'w', newline='', encoding='utf-8-sig') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
        print(f"\n📁 새로운 파일 생성: '{filename}'")

    # ------------------------------------------------------------------------------
    # [2] 크롤링 루프 (페이지 순회)
    # ------------------------------------------------------------------------------
    # 원하는 페이지 범위를 설정하세요 (예: 1페이지부터 20페이지까지)
    target_start_page = 1
    target_end_page = 1

    print(f"\n>>> 크롤링 시작 (페이지 {target_start_page} ~ {target_end_page})")

    for page_no in range(target_start_page, target_end_page + 1):
        try:
            print(f"\n--- [Page {page_no}] 목록 수집 중 ---")

            # 1. 목록 페이지 접속
            response = requests.get(magazine_list_url + str(page_no), headers=headers, timeout=10)
            if response.status_code != 200:
                print(f"페이지 접속 실패: {response.status_code}")
                continue

            soup = BeautifulSoup(response.text, 'html.parser')

            # 2. 목록에서 아이템 추출 (이전 대화에서 확인한 구조: .theme_list .thumbnail)
            items = soup.select('.theme_list .thumbnail')

            if not items:
                print("더 이상 게시물이 없습니다. 종료합니다.")
                break

            # 3. 각 아이템별 상세 페이지 크롤링
            for item in tqdm(items, desc=f"Page {page_no} 상세 수집"):
                try:
                    # 링크 추출
                    href = item.get('href')
                    if not href: continue

                    full_link = base_domain + href

                    # 이미 수집한 링크면 패스
                    if full_link in processed_links:
                        continue

                    # 상세 페이지 접속
                    detail_res = requests.get(full_link, headers=headers, timeout=10)
                    if detail_res.status_code != 200: continue

                    d_soup = BeautifulSoup(detail_res.text, 'html.parser')

                    # --- 데이터 추출 (매거진/팁 구조) ---

                    # (1) 제목
                    # 상세 페이지 내부의 제목 태그 (보통 <h3> 또는 .view2_summary_st3)
                    # 만약 구조가 다르면 목록에서 가져온 제목을 써도 되지만, 상세페이지 제목이 정확함
                    title_tag = d_soup.select_one('.view2_summary h3')
                    title = title_tag.get_text(strip=True) if title_tag else "제목 없음"

                    # (2) 메인 이미지
                    main_img_tag = d_soup.select_one('#main_thumbs')
                    main_img = main_img_tag['src'] if main_img_tag else "None"

                    # (3) 요약(인트로) 글
                    intro_tag = d_soup.select_one('#recipeIntro')
                    intro = intro_tag.get_text(strip=True) if intro_tag else "None"

                    # (4) 본문 내용 (Steps)
                    # 팁도 레시피처럼 view_step_cont 구조를 사용하는 경우가 많음
                    step_divs = d_soup.select('div.view_step_cont')
                    step_list = []

                    if step_divs:
                        for i, step_div in enumerate(step_divs):
                            # 텍스트
                            desc_tag = step_div.select_one('div.media-body')
                            desc = desc_tag.get_text(strip=True) if desc_tag else ""
                            # 이미지
                            s_img_tag = step_div.select_one('img')
                            s_img = s_img_tag['src'] if s_img_tag else ""

                            step_list.append(f"[{i+1}] {desc} || {s_img}")
                    else:
                        # step 구조가 없는 통이미지/통글 형태일 경우 (예외처리)
                        # view2_view_cont 내의 텍스트를 긁어옴
                        body_content = d_soup.select_one('.view2_view_cont')
                        if body_content:
                            step_list.append(body_content.get_text(strip=True))

                    content_text = "\n".join(step_list)

                    # --- CSV 저장 ---
                    row_data = {
                        'Link': full_link,
                        'Title': title,
                        'Main_Thumbnail': main_img,
                        'Intro_Summary': intro,
                        'Content_Steps': content_text
                    }

                    with open(filename, 'a', newline='', encoding='utf-8-sig') as csvfile:
                        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                        writer.writerow(row_data)

                    processed_links.add(full_link)

                    # 차단 방지를 위한 대기
                    time.sleep(random.uniform(0.5, 1.0))

                except Exception as e:
                    print(f"  [Error] 상세 페이지 처리 중 오류: {e}")
                    continue

        except Exception as e:
            print(f"[Page Error] 페이지 {page_no} 처리 중 오류: {e}")

    print(f"\n🎉 크롤링 완료! 데이터가 '{filename}'에 저장되었습니다.")

if __name__ == "__main__":
    main()
# Out:
# ============================================================
#  [만개의 레시피 - 매거진/꿀팁 크롤러] 시작
# ============================================================
#
# 📁 새로운 파일 생성: '10000recipe_magazine_20260108_160906.csv'
#
# >>> 크롤링 시작 (페이지 1 ~ 1)
#
# --- [Page 1] 목록 수집 중 ---
# Page 1 상세 수집: 100%|██████████| 20/20 [00:25<00:00,  1.28s/it]
# 🎉 크롤링 완료! 데이터가 '10000recipe_magazine_20260108_160906.csv'에 저장되었습니다.

# %%
df = pd.read_csv('10000recipe_magazine_20260108_160906.csv')
df
# Out:
#                                           Link  \
# 0   https://www.10000recipe.com/recipe/7024170
# 1   https://www.10000recipe.com/recipe/7023971
# 2   https://www.10000recipe.com/recipe/6997356
# 3   https://www.10000recipe.com/recipe/6996955
# 4   https://www.10000recipe.com/recipe/6996797
# 5   https://www.10000recipe.com/recipe/6996785
# 6   https://www.10000recipe.com/recipe/6996207
# 7   https://www.10000recipe.com/recipe/6996166
# 8   https://www.10000recipe.com/recipe/6996052
# 9   https://www.10000recipe.com/recipe/6996047
# 10  https://www.10000recipe.com/recipe/6995722
# 11  https://www.10000recipe.com/recipe/6995716
# 12  https://www.10000recipe.com/recipe/6995657
# 13  https://www.10000recipe.com/recipe/6995650
# 14  https://www.10000recipe.com/recipe/6973471
# 15  https://www.10000recipe.com/recipe/6973377
# 16  https://www.10000recipe.com/recipe/6973195
# 17  https://www.10000recipe.com/recipe/6966989
# 18  https://www.10000recipe.com/recipe/6958294
# 19  https://www.10000recipe.com/recipe/6923532
#
#                              Title  \
# 0                 슈퍼푸드 아보카도 손질과 보관
# 1                 브로콜리 손질법/보관법/조리법
# 2                    라면 맛있게 끓이기 2탄
# 3                    라면 맛있게 끓이기 1탄
# 4                           양파 보관법
# 5                      동그랑땡 쉽게 만들기
# 6               물에 씻으면 오히려 안좋은 재료들
# 7                        베이킹소다 활용법
# 8            생라면 먹고 남은 건더기 스프 활용 법
# 9                         과일껍질 활용법
# 10             스테인레스 제품 연마제 제거하는 법
# 11              다양한 간장 어떻게 사용해야할까?
# 12               같은 레시피여도 맛이 다른 이유
# 13             맛술과 미림의 차이점에서 사용법까지
# 14              이쑤시개 없이 꼬치전 만드는 방법
# 15  손만두 예쁘게 빚는방법 4가지... 그리고 보관법까지!
# 16       젤라틴 없는 요플레로 그릭요거트 만드는 꿀팁!
# 17            전자레인지로 밤 껍질 쉽게 까는 방법
# 18              꽃차의 종류와 꽃차 우리는 방법!
# 19  닭의 종류마다 어디에 쓸지가 궁금해~! 닭의 모든것 ★
#
#                                        Main_Thumbnail  \
# 0   https://recipe1.ezmember.co.kr/cache/recipe/20...
# 1   https://recipe1.ezmember.co.kr/cache/recipe/20...
# 2   https://recipe1.ezmember.co.kr/cache/recipe/20...
# 3   https://recipe1.ezmember.co.kr/cache/recipe/20...
# 4   https://recipe1.ezmember.co.kr/cache/recipe/20...
# 5   https://recipe1.ezmember.co.kr/cache/recipe/20...
# 6   https://recipe1.ezmember.co.kr/cache/recipe/20...
# 7   https://recipe1.ezmember.co.kr/cache/recipe/20...
# 8   https://recipe1.ezmember.co.kr/cache/recipe/20...
# 9   https://recipe1.ezmember.co.kr/cache/recipe/20...
# 10  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 11  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 12  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 13  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 14  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 15  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 16  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 17  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 18  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 19  https://recipe1.ezmember.co.kr/cache/recipe/20...
#
#                                         Intro_Summary  \
# 0   슈퍼 푸드로 알려져 있는 아보카도 ! 맛도 좋고 건강에도 좋은 아보카도 간단하게 소...
# 1   브로콜리는 강력한 항암성분인 설포라판이 함유되어있고 해독, 염증, 피부, 눈건강, ...
# 2   라면 맛있게 만들기 제 2탄!이번엔 여러분이 추천해주신 레시피로!어떤 재료를 추천해...
# 3             XX을 넣으면 라면이 맛있어진다?일단 보고 따라해보세요!후회안하실걸요?
# 4   여기도 쓰고 저기도 쓰는 양파어떻게 보관하는게 좋을까?잘못보관하면 금방 썩어버려 아...
# 5   명절마다 먹는 동그랑땡누구나 좋아해 많은 사랑을 받는 요리인데요.평소에도 먹으면 좋...
# 6   씻으면 안되는 재료가 있다는 것 여러분은 알고 계셨나요? 우리가 자주 먹는 재료 중...
# 7   베이킹소다 어떻게 활용하면 좋을까~? 만개가 베이킹소다 활용법 알려드려요! 지금 따...
# 8   생라면 먹고 남은 건더기 스프 활용하기! 남은 건더기 스프는 활용하기 어려워 버리는...
# 9   먹고 남은 과일껍질 어디까지 써봤니?사과, 레몬, 오렌지 등 먹고 남은 과일껍질을어...
# 10  스텐 냄비를 새로 장만하면 반드시 할일!스텐 연마제를 먼저 제거해줘야겠죠?남아있을지...
# 11  국간장? 진간장? 양조간장?이 많은 간장들을 어떻게 사용해야 하는거죠?다양한 간장 ...
# 12  양념 넣는 순서에 따라 맛이 달라진다?손에 잡힌다고 아무거나 넣지말고양념도 순서대로...
# 13  요리하다가 맛술을 넣어야 할지 미림을 넣어야 할지 고민 하시는 분들 많으시죠?또 레...
# 14  한 꼬치전에 한꼬치를 꽂아야 하는 번거로움!꼬치가 없어도 꼬치전 쉽게하는 방법을 알...
# 15  손으로 직접 빚어야 맛있는 만두!만두 예쁘게 빚는 방법 4가지그리고 보관법을 알아보세요!
# 16  그릭요거트!생각보다 비싸서 자주 못 사먹잖아요-!요거트로 유청만 분리하면단단? 쫀쫀...
# 17  알맹이만 쏙! 쉽게 까기 힘든 밤뾰족한 부분에 (+)칼집을 내고전자레인지로 1분 3...
# 18  은은한 향의 꽃차!꽃차 우리면서 잠시 쉬었다 가세요!4가지 꽃차의 종류와 맛!그리고...
# 19  닭 부위는 어디어디 사용하는 것이 좋을까????닭 부위마다 조리법이나 조리법을 다양...
#
#                                         Content_Steps
# 0   [1] 남미에서 재배 멕시코에서 70% 재배되고 아보카도는 눈 건강, 항암 효과, ...
# 1   [1] 고르는법 - 둥굴고 진한 녹색이 좋은 브로콜리이고 노래지고 봉우리가 펴 있다...
# 2   [1] 라면 + 설탕스프와 함께 설탕 반스푼 넣어주면 분식집 맛 그대로!! || h...
# 3   [1] 라면 + 식초라면이 다 끓었을 때쯤 식초 1~2숟가락을 넣어요.식초를 넣으면...
# 4   [1] 뿌리쪽을 잘라내지 않고 껍질을 벗겨요. || https://recipe1.e...
# 5   [1] 모든 재료를 볼에 넣고 섞어 반죽을 만들어요.(채소는 다지고 두부는 물기를 ...
# 6   [1] 요리 재료를 구입했다면 깨끗하게 세척하는 것이 필수 과정입니다. 하지만 물에...
# 7   [1] 첫째 ~ 베이킹 소다는 스텐 조리도구 세척에 좋아요. || https://r...
# 8   [1] 생라면, 라면스프만 빼먹고 남은 후레이크 언젠간 먹어야지 하고 부엌 선반이나...
# 9   [1] 사과 - 사과 껍질에는 '트리테르페놀' 이라는 산성 성분이 함유되어 탄 냄비...
# 10  [1] 적당량의 식용유를 붓고 키친타월로 구석 구석 닦아요.이 과정을 여러번 반복해...
# 11  [1] 양조간장은 메주를 오랫동안 발효 숙성시켜 만든 간장이라 맛과 향이 풍부해요....
# 12  [1] 양념 넣는 순서~ 별거 아닌 거 같지만 무엇을 먼저 넣어야 할지 순간 헷갈릴...
# 13  [1] 미림과 맛술은 고기 잡내, 생선 비린내를 없애기 위해 사용하는 경우가 많아요...
# 14  [1] 모든 재료는 팬사이즈에 맞춰 비슷한 길이와 두께로 손질한다. || https...
# 15  [1] 떡만두국으로 먹으면 더 맛있는 정성 가득'손만두'다진 돼지고기와 당면, 그리...
# 16  [1] 요거트, 볼, 채반, 면보를 준비한다.면보,채반요거트는 원유 95%함유된 것...
# 17  [1] 깨끗이 씻은 밤을 1시간 정도 불린다. || https://recipe1.e...
# 18  [1] 식전 차, 식전 주로 먹기 좋은 꽃차는 1번 우리지 말고 2~3번 더 우려 ...
# 19  [1] 닭조리법 가슴살편 ! 다이어터에게 강추!닭가슴살조리법 || https://r...
